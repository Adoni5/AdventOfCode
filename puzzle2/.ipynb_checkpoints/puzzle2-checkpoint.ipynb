# %%
from collections import Counter

# %%
hello = []
with open("input") as file:
    
    for line in file:
        hello.append(list(line.strip()))
#         hello.append(line)

# %%
hello
# Out:
# [['k',
#   'b',
#   'q',
#   'w',
#   't',
#   'c',
#   'v',
#   'z',
#   'g',
#   'u',
#   'm',
#   'h',
#   'p',
#   'w',
#   'e',
#   'l',
#   'r',
#   'n',
#   'a',
#   'x',
#   'y',
#   'd',
#   'p',
#   'f',
#   'u',
#   'j'],
#  ['k',
#   'b',
#   'q',
#   'w',
#   't',
#   'c',
#   'v',
#   'z',
#   'g',
#   's',
#   'm',
#   'h',
#   'p',
#   'o',
#   'e',
#   'l',
#   'r',
#   'y',
#   'a',
#   'x',
#   'y',
#   'd',
#   'i',
#   'q',
#   'i',
#   'j'],
#  ['k',
#   'b',
#   'q',
#   'w',
#   'p',
#   'c',
#   'v',
#   'z',
#   's',
#   's',
#   'm',
#   'h',
#   'p',
#   'o',
#   'e',
#   'l',
#   'g',
#   'n',
#   'a',
#   'x',
#   'y',
#   'd',
#   'i',
#   'f',
#   'u',
#   'j'],
#  ['k',
#   'b',
#   'q',
#   'g',
#   't',
#   'c',
#   'v',
#   'x',
#   'g',
#   's',
#   'm',
#   'h',
#   'p',
#   'o',
#   'a',
#   'l',
#   'r',
#   'n',
#   'a',
#   'x',
#   'y',
#   'd',
#   'i',
#   'f',
#   'u',
#   'j'],
#  ['k',
#   'b',
#   'q',
#   'w',
#   't',
#   'c',
# ...
